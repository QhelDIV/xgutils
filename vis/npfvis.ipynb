# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %reload_ext autoreload
# %autoreload 2
import logging
import os
import warnings
import matplotlib.pyplot as plt
import torch
#from xgutils import nputil, ptutil, visutil
#from .. import nputil

import numpy as np
import scipy
import copy
import sys
sys.path.append('../')
os.chdir('../../')

# %%
from xgutils import nputil
# Out:
# xgutils.vis.visutil
# xgutils.vis

# %%
from xgutils.vis import npfvis, visutil

# %%
npfvis.plot_1d_unittest()

# %%
from xgutils.data import *
from xgutils import *
import xgutils

# %%
box3d = BoxShapeDataset(dim=3)

# %%
from xgutils.vis import npfvis
data = box3d[0]
pred_ys = np.array([box3d[i]['target_y'] for i in range(50)])
pred_ys[0]=data['target_y']
Xct, Yct, Xtg, Ytg = data['context_x'], data['context_y'], data['target_x'], data['target_y']
img=npfvis.plot_samples(np.zeros((0,3)), np.zeros((0,1)), Xtg, Ytg, pred_ys, dim=3)
visutil.showImg(img)
img=npfvis.plot_samples(Xct, Yct, Xtg, Ytg, pred_ys, dim=3)
visutil.showImg(img)
# Out:
# (3, 256, 256, 4)
# (2, 256, 256, 4)
# (2, 256, 256, 4)
# (2, 256, 256, 4)
# (2, 256, 256, 4)
# (2, 256, 256, 4)
# 12
# (12, 256, 256, 4)
# (3, 256, 256, 4)
# (2, 256, 256, 4)
# (2, 256, 256, 4)
# (2, 256, 256, 4)
# (2, 256, 256, 4)
# (2, 256, 256, 4)
# 12
# (12, 256, 256, 4)
# (<Figure size 1536x512 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f0b6230b7d0>)
